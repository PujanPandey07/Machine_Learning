# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\dell\anaconda3\envs\campusx\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\envs\campusx\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\envs\campusx\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\envs\campusx\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\envs\campusx\lib\site-packages (from requests) (2025.4.26)

# %%
import pandas as pd
import requests

# %%
url="https://streaming-availability.p.rapidapi.com/shows/%7Btype%7D/%7Bid%7D "
headers={
    "X-RapidAPI-Key": "ac3cc52473msh7e21275bfb3de1bp17ac82jsn0a36b2907c63'",
    "X-RapidAPI-Host": "streaming-availability.p.rapidapi.com"
}

requests.get(url, headers=headers,)
# Out:
# <Response [403]>

# %%
if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print("Error:", response.status_code, response.text)
# Out:
# Error: 401 {"message":"Invalid API key. Go to https:\/\/docs.rapidapi.com\/docs\/keys for more info."}
